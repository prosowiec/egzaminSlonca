# %%
import pandas as pd

cols = ['Question', 'Option A', 'Option B', 'Option C', 'Option D', 'Option E', 'Correct Answer', 'Explanation']
q = []

# 1-10: Anatomy & Microanatomy
q.append(["What is the main function of the periodontium?", "To form enamel", "To fix the tooth to the bone tissue", "To regenerate dentin", "To form the pulp", "To nourish the crown", "Option B", "The periodontium fixes the tooth to the bone tissue with some elasticity and maintains oral mucosa integrity."])
q.append(["Which of the following tissues is NOT part of the periodontium?", "Gingiva", "Periodontal ligament", "Cementum", "Alveolar bone", "Dentin", "Option E", "The periodontium consists of the gingiva, periodontal ligament, cementum, and alveolar bone."])
q.append(["What constitutes the protective periodontium?", "Cementum and alveolar bone", "Gingiva and junctional epithelium", "Periodontal ligament and cementum", "Alveolar bone and periodontal ligament", "Dentin and pulp", "Option B", "The protective periodontium is formed by the gingiva and the dentogingival junction or junctional epithelium."])
q.append(["The mucogingival junction separates which two structures?", "Free gingiva and attached gingiva", "Attached gingiva and alveolar mucosa", "Cementum and enamel", "Periodontal ligament and alveolar bone", "Crown and root", "Option B", "The mucogingival junction separates the attached gingiva from the loose and darker red alveolar mucosa."])
q.append(["Healthy gingiva is typically described as having what color?", "Bright red", "Dark brown", "Pale pink or coral pink", "Bluish-purple", "White", "Option C", "Healthy gingiva is pale pink in color (coral pink or salmon pink)."])
q.append(["What gives the attached gingiva its characteristic 'orange peel' appearance?", "Loss of keratinization", "Inflammatory infiltrate", "Connective tissue papillae fusing with epithelial ridges", "Accumulation of bacterial plaque", "Loss of collagen fibers", "Option C", "The interdigitation between connective tissue and epithelium creates depressions, giving it a stippled or orange peel appearance."])
q.append(["The oral epithelium is mainly composed of which type of cells?", "Melanocytes", "Keratinocytes", "Langerhans cells", "Merkel cells", "Fibroblasts", "Option B", "The majority of cells in the oral epithelium are keratinocytes, characterized by their ability to produce cytokeratin."])
q.append(["What is the estimated epithelial renewal time for the oral epithelium?", "1 - 3 days", "4 - 6 days", "10 - 30 days", "40 - 50 days", "60 - 90 days", "Option C", "The surface of the epithelium is constantly renewed, taking about 10 - 30 days."])
q.append(["Which cells in the oral epithelium are responsible for producing melanin?", "Keratinocytes", "Langerhans cells", "Merkel cells", "Melanocytes", "Osteoblasts", "Option D", "Melanocytes are dendritic cells that produce melanin, which protects from actinic radiation."])
q.append(["What is the primary function of Merkel cells in the oral epithelium?", "Phagocytosis", "Melanin production", "Collagen synthesis", "Tactile reception", "Antigen presentation", "Option D", "Merkel cells are located in the deepest layers of the epithelium, harbor nerve endings, and are identified as tactile receptors."])

# 11-20: Periodontal Histology (Epithelium, PDL, Cementum)
q.append(["Which structure forms the basal lamina?", "Lamina lucida and lamina densa", "Stratum corneum and stratum granulosum", "Stratum basale and stratum spinosum", "Collagen and elastin", "Reticulin and oxytalan", "Option A", "At the ultramicroscopic level, the basal lamina is formed by the lamina lucida and the lamina densa."])
q.append(["Does the sulcular epithelium normally possess a stratum corneum?", "Yes, it is highly keratinized", "No, it lacks a granular stratum and corneum stratum", "Yes, but only in smokers", "Yes, it is parakeratinized", "It depends on the patient's age", "Option B", "It is a thin, non-keratinized stratified squamous epithelium and lacks a granular stratum and corneum stratum."])
q.append(["What is the turnover rate of the junctional epithelium?", "1 - 3 days", "4 - 6 days", "10 - 30 days", "40 - 50 days", "More than 60 days", "Option B", "The junctional epithelium is in constant renewal with a turnover rate of 4-6 days."])
q.append(["Which type of collagen is the most common in the gingival connective tissue?", "Type I", "Type II", "Type III", "Type IV", "Type VII", "Option A", "The most common collagen in the mucosa, as well as in skin, bone, dentin, and cement, is type I."])
q.append(["What cell type is predominant in the lamina propria of the gingiva?", "Macrophages", "Neutrophils", "Fibroblasts", "Osteoblasts", "Cementoblasts", "Option C", "Fibroblasts constitute 65% of the cells and are the predominant cell type in the lamina propria."])
q.append(["What is the approximate width of the periodontal ligament (PDL)?", "0.01 mm", "0.2 mm", "1.0 mm", "2.0 mm", "5.0 mm", "Option B", "The thickness of the periodontal ligament is about 0.2 mm (200 micrometers), although with variations."])
q.append(["What are Sharpey fibers?", "Fibers that form the stratum corneum", "Fibers that connect the gingiva to the tongue", "Fiber bundles inserted at one end in the cementum and the other in the alveolar bone", "Fibers that form the acquired pellicle", "Fibers that innervate the pulp", "Option C", "Sharpey fibers are fiber bundles inserted at one end in the cementum and the other in the dense lamina of the alveolar bone."])
q.append(["Which group of periodontal ligament fibers is the largest and bears vertical masticatory stresses?", "Cresto-alveolar", "Horizontal", "Inter-radicular", "Apical", "Obliques", "Option E", "Oblique fibers are the largest group and bear the brunt of vertical masticatory stresses."])
q.append(["Which type of cementum is formed first and does not contain cells?", "Cellular cementum", "Acellular cementum", "Secondary cementum", "Tertiary cementum", "Fascicular cementum", "Option B", "Acellular cementum is the first cementum formed, does not contain cells, and usually covers the cervical third or half of the root."])
q.append(["The alveolar bone wall adjacent to the periodontal ligament is perforated by numerous canals known as:", "Haversian canals", "Volkmann canals", "Sharpey canals", "Root canals", "Dental tubules", "Option B", "Fascicular bone is perforated by numerous Volkmann conduits, where blood vessels and nerve fibers pass."])

# 21-30: Plaque Hypotheses and Biofilm
q.append(["Which cells are responsible for bone resorption in the alveolar bone?", "Osteoblasts", "Fibroblasts", "Cementoblasts", "Osteoclasts", "Macrophages", "Option D", "The resorption of bone is carried out by multinucleated cells called osteoclasts, located in Howship lacunae."])
q.append(["Which hypothesis stated that periodontal disease was the result of an accumulation of plaque over time as a biomass?", "Specific Plaque Hypothesis", "Ecological Plaque Hypothesis", "Non-specific Plaque Hypothesis", "Keystone Pathogen Hypothesis", "Dysbiosis Hypothesis", "Option C", "The Non-specific Plaque Hypothesis conceived dental plaque as a biomass where quantity dictates the pathogenic effect."])
q.append(["Who developed the Specific Plaque Hypothesis in 1979?", "Theilade", "Loesche", "Marsh", "Costerton", "Socransky", "Option B", "The Specific Plaque Hypothesis was proposed by Loesche in 1979."])
q.append(["What does the Ecological Plaque Hypothesis suggest?", "Only specific bacteria cause disease", "Plaque quantity alone causes disease", "Both the quantity of plaque and its microbial composition contribute to the transition from health to disease", "Diet is the sole cause of periodontitis", "Viruses are the main cause of periodontitis", "Option C", "The Ecological Plaque Hypothesis states that both quantity and composition, driven by environmental factors, contribute to disease."])
q.append(["What makes up 75-80% of the total volume of a biofilm?", "Bacterial cells", "Saliva", "Matrix / Glycocalyx", "White blood cells", "Red blood cells", "Option C", "The Matrix / Glycocalyx composes 75-80% of the total volume of a biofilm."])
q.append(["What is quorum sensing?", "The ability of bacteria to move rapidly", "Bacterial communication through signaling molecules to regulate gene expression", "The process of bone resorption", "The formation of the acquired pellicle", "The mineralization of plaque into calculus", "Option B", "Quorum sensing is the process by which bacteria communicate using chemical signals to regulate specific gene expression."])
q.append(["What forms immediately after the immersion of a solid substrate into the oral cavity?", "Dental calculus", "Materia alba", "Acquired pellicle", "Periodontal pocket", "Granulation tissue", "Option C", "Hydrophobic macromolecules are adsorbed to form the acquired pellicle immediately after cleaning a solid surface."])
q.append(["During the first 4-8 hours of plaque formation, between 60% and 80% of the bacteria belong to which genus?", "Porphyromonas", "Treponema", "Streptococcus", "Fusobacterium", "Aggregatibacter", "Option C", "In the first 4-8 hours, 60-80% of bacteria belong to the genus Streptococcus."])
q.append(["Which substance is described as a soft, white accumulation of bacteria, decaying food, and shed cells lacking an organized structure?", "Dental calculus", "Acquired pellicle", "Materia alba", "Biofilm matrix", "Gingival crevicular fluid", "Option C", "Materia alba consists of soft, white accumulations lacking an organized structure, easily removed by irrigators."])
q.append(["What is the predominant inorganic component of dental calculus?", "Calcium carbonate", "Magnesium whitlockite", "Hydroxyapatite", "Brushite", "Octacalcium phosphate", "Option C", "Hydroxyapatite represents 58% of the main crystalline forms in dental calculus."])

# 31-40: Microbiology (Complexes and Pathogens)
q.append(["According to Socransky's complexes, which of the following bacteria belongs to the Red Complex?", "Streptococcus sanguinis", "Fusobacterium nucleatum", "Porphyromonas gingivalis", "Capnocytophaga", "Eikenella corrodens", "Option C", "The Red Complex includes Porphyromonas gingivalis, Tannerella forsythia, and Treponema denticola."])
q.append(["Which bacterial species is defined as a 'bridging bacterium' because it facilitates the coaggregation of other species?", "Aggregatibacter actinomycetemcomitans", "Streptococcus mutans", "Treponema denticola", "Fusobacterium nucleatum", "Campylobacter rectus", "Option D", "Fusobacterium nucleatum is a bridging bacterium that facilitates the coaggregation of T. denticola and P. gingivalis."])
q.append(["Aggregatibacter actinomycetemcomitans is strongly associated with which condition?", "Dental caries", "Aggressive periodontitis", "Oral candidiasis", "Erythema multiforme", "Lichen planus", "Option B", "It has been strongly associated with aggressive periodontitis, both localized and generalized forms."])
q.append(["Gingipains are powerful virulence factors produced by which pathogen?", "Tannerella forsythia", "Aggregatibacter actinomycetemcomitans", "Porphyromonas gingivalis", "Fusobacterium nucleatum", "Treponema denticola", "Option C", "Gingipains are multifunctional protein enzymes (virulence factors) produced by P. gingivalis."])
q.append(["Treponema denticola belongs to which group of microorganisms?", "Gram-positive cocci", "Spirochetes", "Gram-positive bacilli", "Fungi", "Viruses", "Option B", "Spirochetes are Gram-negative, helical, highly motile microorganisms, with Treponema denticola being the most significant in periodontics."])
q.append(["Streptococcus sanguinis is considered a beneficial bacterium because it produces what substance that inhibits A. actinomycetemcomitans?", "Lactic acid", "Gingipains", "Hydrogen peroxide (H2O2)", "Endotoxins", "Beta-lactamase", "Option C", "S. sanguinis produces hydrogen peroxide (H2O2) that can inhibit the development of A. actinomycetemcomitans."])
q.append(["As periodontal health progresses towards periodontitis, the oral flora shifts from Gram-positive to what?", "Viruses", "Fungi", "Gram-negative", "Aerobic bacilli", "Yeast", "Option C", "The microbial flora shifts from gram-positive to gram-negative, from cocci to bacilli/spirochetes, and from facultative to strict anaerobes."])
q.append(["In Koch's postulates, what is the first requirement?", "The microorganism must be eliminated by antibiotics", "The microorganism must be routinely isolated from diseased individuals", "The microorganism must produce gingipains", "The microorganism must be a spirochete", "The microorganism must form a biofilm", "Option B", "The first postulate is that the organism must be routinely isolated from diseased individuals."])
q.append(["What does the Keystone Pathogen Hypothesis suggest?", "Plaque quantity is the only disease driver", "A dominant species influences inflammation merely through abundance", "Pathogens like P. gingivalis trigger inflammation even in low numbers by altering host response", "Viruses act as keystones in periodontitis", "Beneficial bacteria cause disease when overgrown", "Option C", "Keystone pathogens can trigger inflammation even in low numbers by altering the host immune response and creating dysbiosis."])
q.append(["Which enzyme produced by bacteria inactivates beta-lactam antibiotics like amoxicillin?", "Catalase", "Superoxide dismutase", "Beta-lactamase", "Elastase", "Cellulase", "Option C", "Bacteria in biofilms can produce beta-lactamase, which inactivates beta-lactam antibiotics such as amoxicillin."])

# 41-50: Pathogenesis and Mediators
q.append(["Which molecule, derived from the subgingival microbiota, acts as an endotoxin to elicit strong immune responses?", "Prostaglandin E2", "Interleukin-1", "Lipopolysaccharides (LPS)", "Matrix metalloproteinases", "Tumor necrosis factor", "Option C", "Lipopolysaccharides (LPS) are found in the outer membrane of gram-negative bacteria and act as endotoxins."])
q.append(["Which host-derived inflammatory mediator is primarily responsible for inducing osteoclastic bone resorption in periodontitis?", "Interleukin-10", "Prostaglandin E2 (PGE2)", "Beta-lactamase", "Hydrogen sulfide", "Ammonia", "Option B", "PGE2 induces the secretion of MMPs and osteoclastic bone resorption, playing a fundamental role in bone destruction."])
q.append(["What is the primary function of Matrix Metalloproteinases (MMPs) in inflamed periodontal tissues?", "Synthesize new bone", "Produce antibodies", "Degrade connective tissue / collagen", "Neutralize bacterial toxins", "Inhibit osteoclasts", "Option C", "MMPs, such as MMP-1, are enzymes whose excess secretion leads to the degradation of connective tissue in inflamed periodontium."])
q.append(["Which cells are considered the first line of innate immune defense, migrating through the junctional epithelium to phagocytose bacteria?", "B lymphocytes", "T lymphocytes", "Eosinophils", "Polymorphonuclear leukocytes (PMNs / Neutrophils)", "Osteoblasts", "Option D", "PMNs (Neutrophils) act as the first line of innate immune defense, migrating to phagocytose bacteria."])
q.append(["What is the primary function of B Lymphocytes in the adaptive immune system?", "Phagocytosis of bacteria", "Formation of the acquired pellicle", "Transformation into plasma cells that produce antibodies", "Direct lysis of infected cells", "Secretion of MMPs", "Option C", "When a B cell contacts its specific antigen, it transforms into a plasma cell that produces antibodies."])
q.append(["Which anti-inflammatory cytokine helps regulate the immune response in periodontitis?", "IL-1 beta", "TNF-alpha", "PGE2", "IL-10", "MMP-8", "Option D", "IL-10 and TGF-beta are anti-inflammatory cytokines that act as part of a complex network of mediators."])
q.append(["The Membrane Attack Complex (MAC) is the final lytic pathway of which immune system component?", "T Lymphocytes", "B Lymphocytes", "Complement System", "Macrophages", "Fibroblasts", "Option C", "The MAC is formed by the activation of the Complement System, causing the final lytic burst of the microorganism."])
q.append(["What condition is characterized by a severe Vitamin C deficiency causing spongy, hemorrhagic, and swollen gingival lesions?", "Diabetes Mellitus", "Leukemia", "Scurvy", "Lichen Planus", "Pemphigus Vulgaris", "Option C", "Severe Vitamin C deficiency, or scurvy, impairs collagen synthesis resulting in weakened capillary walls and severe gingival bleeding."])
q.append(["Which of the following medications is a calcium channel blocker associated with drug-induced gingival enlargement?", "Phenytoin", "Cyclosporine A", "Nifedipine", "Amoxicillin", "Ibuprofen", "Option C", "Nifedipine (along with Verapamil and Diltiazem) is a calcium channel blocker associated with 15-20% incidence of gingival enlargement."])
q.append(["According to Page and Schroeder, which histopathological stage is characterized by a predominance of plasma cells and alveolar bone resorption?", "Initial gingivitis", "Early gingivitis", "Established gingivitis", "Periodontitis", "Gingival health", "Option D", "The Periodontitis stage is characterized by apical proliferation of junctional epithelium, predominance of plasma cells, and alveolar bone resorption."])

# 51-60: Risk Factors, Systemic Diseases & 2017 Classification
q.append(["How does smoking primarily affect the clinical presentation of periodontal disease?", "It increases gingival bleeding significantly", "It masks clinical signs of inflammation due to microvascular vasoconstriction", "It increases salivary flow", "It causes rapid enamel erosion", "It stimulates osteoblast proliferation", "Option B", "Smoking causes microvascular vasoconstriction and fibrosis, which can mask clinical signs like bleeding on probing."])
q.append(["Which of the following is a key characteristic of Pregnancy-associated gingivitis?", "Severe bone loss within 1 month", "Vesicle formation on the palate", "Exaggerated inflammatory response to relatively low amounts of plaque", "Complete loss of interdental papillae", "Decreased gingival exudate", "Option C", "In pregnancy, a combination of hormones and plaque may increase severity, leading to severe inflammation with low amounts of plaque."])
q.append(["Which condition presents as an acute viral infection characterized by multiple small vesicles that rupture to form painful ulcerations, often with systemic fever?", "Erythema multiforme", "Primary herpetic gingivostomatitis", "Lupus erythematosus", "Lichen planus", "Candidiasis", "Option B", "Primary herpetic gingivostomatitis is caused by HSV-1/2, characterized by painful vesicles, ulcerations, and systemic signs like fever."])
q.append(["Which autoimmune condition presents clinically as desquamative gingivitis and typically shows a positive Nikolsky sign?", "Lichen planus", "Erythema multiforme", "Pemphigus vulgaris", "Histoplasmosis", "Leukemia", "Option C", "Pemphigus vulgaris features intraepithelial bullae and demonstrates a positive Nikolsky sign."])
q.append(["What are Wickham striae?", "Lines of bone loss on a radiograph", "White reticular striations characteristically seen in Lichen planus", "Bacterial tracks in the acquired pellicle", "Scratches on enamel from abrasive brushing", "Stretch marks on the lips", "Option B", "Wickham striae are white papules and striations forming a reticular pattern, characteristic of Lichen planus."])
q.append(["In the 2017 World Workshop Classification, which two traditional terms for periodontitis were eliminated?", "Gingivitis and Periodontitis", "Chronic and Aggressive periodontitis", "Localized and Generalized periodontitis", "Necrotizing and Ulcerative periodontitis", "Mild and Severe periodontitis", "Option B", "The new classification eliminated the terms chronic and aggressive periodontitis, replacing them with a Staging and Grading system."])
q.append(["In the 2017 Classification, what is the primary determinant used to establish the 'Stage' of periodontitis?", "Bleeding on probing", "Number of missing teeth", "Interdental Clinical Attachment Loss (CAL)", "Patient age", "Salivary flow rate", "Option C", "Clinical attachment loss (CAL) is the primary determinant of Stage. If unavailable, radiographic bone loss can be used."])
q.append(["What does the 'Grade' reflect in the 2017 Periodontitis Classification?", "The total number of teeth present", "The risk or evidence of disease progression and expected response to treatment", "The amount of calculus on the teeth", "The depth of the gingival sulcus in millimeters", "The specific bacteria present in the biofilm", "Option B", "Grade provides information about the biological behavior, including the rate of disease progression and impact on systemic health."])
q.append(["Which two main risk factors are used as 'Grade Modifiers' in the 2017 classification?", "Stress and poor diet", "Age and gender", "Smoking and Diabetes Mellitus (HbA1c levels)", "Hypertension and hyperlipidemia", "Alcohol consumption and bruxism", "Option C", "Smoking and Diabetes Mellitus (measured by HbA1c) are the main risk modifiers that can alter the Grade."])
q.append(["What defines a Recession Type 1 (RT1) according to the new mucogingival classification?", "Recession associated with loss of interproximal attachment greater than buccal attachment loss", "Gingival recession with no loss of interproximal attachment", "Recession caused exclusively by orthodontic forces", "Recession combined with deep periodontal pockets", "Recession affecting only palatal surfaces", "Option B", "RT1 is gingival recession with no loss of interproximal attachment, where the interproximal CEJ is clinically not detectable."])

# 61-70: Radiography and Periodontal Abscess
q.append(["What is the ALARA principle in radiography?", "Always Look At Radiographs Accurately", "As Low As Reasonably Achievable (for radiation exposure)", "All Lesions Are Radiographically Apparent", "Acquire Lateral And Rostral Angles", "Anatomical Landmarks Are Rarely Accurate", "Option B", "The ALARA principle means 'as low as reasonably achievable' regarding radiation exposure."])
q.append(["Why is the interdental bone used primarily for evaluating bone changes in periodontal disease?", "It is the only bone that resorbs", "Buccal and palatal bone plates are obscured by the dense radiopaque root structure", "It is easier to access clinically", "It contains more marrow spaces", "It lacks a lamina dura", "Option B", "The relatively dense/radiopaque root structure obscures the buccal and palatal/lingual bone plates on radiographs."])
q.append(["Which radiographic technique provides a more accurate projection of the alveolar bone level without distortion?", "Bisecting-angle technique", "Long-cone paralleling technique", "Panoramic radiography", "Cephalometric radiography", "Water's projection", "Option B", "The long-cone paralleling technique provides a more accurate projection of the alveolar bone level."])
q.append(["In a healthy adolescent, what is the typical distance between the cementoenamel junction (CEJ) and the alveolar crest on a radiograph?", "0 mm", "About 2 mm", "4 mm", "6 mm", "10 mm", "Option B", "Most studies in adolescents suggest a distance of about 2 mm between the CEJ and the alveolar crest reflects a normal periodontium."])
q.append(["Which feature of a periodontal defect cannot be accurately determined from conventional 2D radiographs?", "The level of the interdental crest", "The presence of a continuous lamina dura", "The internal morphology or depth of crater-type defects on buccal/lingual surfaces", "The presence of gross horizontal bone loss", "The presence of subgingival calculus on proximal surfaces", "Option C", "Because radiographs are 2D, they do not indicate the internal morphology or depth of crater-type defects on buccal/lingual surfaces."])
q.append(["What is a typical radiographic presentation of a periodontal abscess?", "A massive multilocular radiolucency in the ramus", "A discrete radiolucent area along the lateral surface of the root", "A radiopaque mass attached to the apex", "A widening of the entire mandibular canal", "Generalized horizontal bone loss", "Option B", "The typical radiographic appearance of a periodontal abscess is a discrete radiolucent area along the lateral surface of the root."])
q.append(["Which of the following radiographic changes is commonly associated with Trauma from Occlusion?", "Formation of enamel pearls", "Narrowing of the entire pulp chamber", "Widening of the periodontal ligament (PDL) space", "Hypercementosis at the cervical third", "Complete obliteration of the PDL space", "Option C", "Trauma from occlusion can produce a loss of the lamina dura and widening of the PDL space."])
q.append(["What are Enamel Pearls?", "Calculus deposits that have calcified intensely", "Enamel deposits located along the root surface extending beyond the CEJ", "Resin restorations mimicking enamel", "Cysts filled with enamel-like fluid", "Benign tumors of the gingiva", "Option B", "Enamel pearls are enamel deposits located along the root surface, often preventing connective tissue attachment and related to furcation lesions."])
q.append(["How is Clinical Attachment Level (CAL) calculated if the gingival margin is apical to the CEJ (gingival recession)?", "Subtract probing depth from recession", "It is equal to the probing depth", "Add the probing depth and the recession amount", "Divide probing depth by two", "Measure only the recession", "Option C", "If the gingival margin is apical to the CEJ, you add the probing depth and the recession to determine the clinical attachment level."])
q.append(["According to Lang et al. (1991), what is the negative predictive value of the absence of bleeding on probing for periodontal disease progression?", "6%", "25%", "50%", "75%", "98%", "Option E", "The absence of bleeding on probing is a strong indicator of periodontal health, with a negative predictive value of 98%."])

# 71-80: Clinical Exam, Indices, and Furcations
q.append(["Which specific instrument is designed to evaluate the horizontal component of a furcation lesion?", "Florida probe", "Nabers probe", "WHO probe", "Sickle scaler", "Gracey curette", "Option B", "The Nabers probe is specifically designed to explore and evaluate the horizontal penetration of furcation lesions."])
q.append(["According to the furcation classification, what defines a Grade 3 (Complete) furcation?", "Probe enters but does not exceed one third of the tooth width", "Probe passes beyond one third but not entirely through", "Probe passes through the entire width of the tooth crown from one side to the other", "Furcation is only visible radiographically", "Furcation is covered by an enamel pearl", "Option C", "In a Grade 3 furcation, the probe passes completely through the entire width of the tooth from one side to the other."])
q.append(["Which term describes occlusal wear caused by functional contact between opposing teeth?", "Abrasion", "Abfraction", "Erosion", "Attrition", "Resorption", "Option D", "Attrition is occlusal wear caused by functional contact between opposing teeth, often presenting on incisal/occlusal surfaces."])
q.append(["Wedge-shaped cervical lesions, often located on the buccal surface and hypothetically caused by unfavorable occlusal loading, are called:", "Erosion", "Abrasion", "Abfraction", "Attrition", "Caries", "Option C", "Abfraction (non-carious cervical lesions) are wedge-shaped lesions hypothetically resulting from occlusal loading causing flexion and microfractures."])
q.append(["According to the CPITN (Community Periodontal Index of Treatment Needs), what does a Code 3 indicate?", "Healthy periodontium", "Bleeding on probing only", "Presence of supra/subgingival calculus", "Probing depths between 3.5 and 5.5 mm", "Probing depths 5.5 mm or more", "Option D", "Code 3 indicates probing depths between 3.5 and 5.5 mm, where the black band of the WHO probe remains partially visible."])
q.append(["The Papilla Bleeding Index (PBI) scores bleeding intensity from 1 to 4. What does Grade 4 represent?", "A single bleeding point", "A fine line of blood", "The interdental triangle filled with blood", "Profuse bleeding where blood flows by gravity into the interdental region", "No bleeding", "Option D", "Grade 4 represents profuse bleeding after probing, where blood flows by gravity into the interdental region."])
q.append(["When evaluating the prognosis of a tooth, which factor implies an 'Impossible' prognosis requiring extraction according to McGuire & Nunn?", "Class I furcation", "25% attachment loss", "Mobility > III or inadequate insertion for tooth maintenance", "Deep developmental groove", "Presence of enamel pearl", "Option C", "An impossible prognosis is defined by inadequate insertion for tooth maintenance, Mobility > III, or untreatable root caries requiring extraction."])
q.append(["A patient presents with a deep periodontal pocket, loss of vitality in the affected tooth, and a periapical lesion communicating with the pocket. This condition is known as:", "Necrotizing stomatitis", "Endoperiodontal lesion", "Primary herpetic gingivostomatitis", "Erythema multiforme", "Pyogenic granuloma", "Option B", "Endoperiodontal lesions involve both pulp and periodontal tissues, typically presenting with deep pockets reaching the apex and altered pulp vitality."])
q.append(["During a clinical examination, 'edematous' gingiva is typically characterized by:", "Firm, stippled, and opaque appearance", "Thick and rounded margins", "Smooth, shiny, soft, and reddish appearance", "Heavy keratinization", "Presence of Wickham striae", "Option C", "Edematous gingival reactions are characterized by smooth, shiny, soft, and reddish gingiva."])
q.append(["What is the primary characteristic of 'fibrotic' gingival inflammation?", "Smooth and shiny surface", "Bluish-purple color with vesicles", "Firmer gingiva, stippled and opaque, with a thick rounded margin", "Spontaneous profuse bleeding", "Ulceration of the papillae", "Option C", "Fibrotic inflammation presents as firmer gingiva, stippled and opaque, with a thick and rounded margin."])

# 81-90: Mechanical and Chemical Control
q.append(["According to the classification of antiseptic agents, what is the substantivity of 1st Generation Agents?", "Less than 6 hours", "8 to 12 hours", "24 hours", "48 hours", "1 week", "Option A", "1st Generation Agents have low substantivity, usually less than 6 hours, and are quickly removed by saliva."])
q.append(["Chlorhexidine is classified as a 2nd Generation Agent due to its high substantivity. How long is its substantivity?", "1 to 2 hours", "3 to 5 hours", "8 to 12 hours", "24 to 48 hours", "7 days", "Option C", "Chlorhexidine has high substantivity, adhering easily and releasing slowly over 8 to 12 hours."])
q.append(["What is the mechanism of action of Chlorhexidine at high concentrations?", "Stimulates bacterial growth", "Inhibits viral replication only", "Precipitates plasma proteins causing a bactericidal effect", "Promotes plaque mineralization", "Acts solely as a fluoride donor", "Option C", "At high concentrations, Chlorhexidine precipitates plasma proteins, exerting a bactericidal effect."])
q.append(["Which of the following is a common adverse effect of Chlorhexidine mouthwash?", "Gingival hyperplasia", "Yellow/brown staining on hard and soft oral surfaces", "Severe bone resorption", "Enamel hypoplasia", "Increased salivary flow", "Option B", "A common adverse effect is variable yellow/brown staining on hard/soft surfaces, accentuated by certain foods and drinks."])
q.append(["Why is it recommended to wait 30 minutes between brushing with regular toothpaste and rinsing with Chlorhexidine?", "To allow teeth to remineralize", "Chlorhexidine is inactivated by anionic detergents like sodium lauryl sulphate in toothpaste", "To prevent burning the tongue", "To maximize fluoride absorption", "To avoid enamel microfractures", "Option B", "Chlorhexidine is inactivated by anionic agents (sodium lauryl sulphate) found in detergents of regular toothpastes."])
q.append(["Triclosan is a 1st generation broad-spectrum agent. Why has its use been restricted in the European Union?", "It causes severe tooth staining", "It is highly teratogenic", "It has an impact on the environment (not biodegradable) and safety concerns", "It accelerates calculus formation", "It interacts negatively with dental implants", "Option C", "Triclosan is restricted because it is not biodegradable (environmental impact) and for safety reasons evaluated by EU scientific committees."])
q.append(["Which systemic antibiotic is particularly effective against strict Gram-negative anaerobic bacteria like P. gingivalis and is often used in combination with Amoxicillin?", "Erythromycin", "Metronidazole", "Spiramycin", "Clindamycin", "Azithromycin", "Option B", "Metronidazole is highly effective against strict Gram-negative anaerobes and is often combined with Amoxicillin in aggressive cases."])
q.append(["When using manual toothbrushes, which brushing technique is specifically designed to disrupt plaque at the gingival margin and inside the sulcus by angling bristles 45 degrees towards the root?", "Stillman technique", "Charters technique", "Bass technique", "Fones technique", "Scrub technique", "Option C", "The Bass technique angles the bristles 45 degrees toward the root, penetrating the sulcus slightly to disrupt plaque."])
q.append(["The Charters brushing technique directs the toothbrush bristles in which direction?", "Towards the gingival sulcus", "Directly perpendicular to the tooth", "Away from the gingiva, pointing toward the occlusal or incisal surface", "Parallel to the occlusal plane", "In a purely horizontal scrub motion", "Option C", "The Charters technique points bristles away from the gingiva toward the occlusal/incisal surface, useful for open embrasures/orthodontics."])
q.append(["How much interproximal plaque can correctly applied dental floss remove?", "Up to 20%", "Up to 40%", "Up to 60%", "Up to 80%", "100%", "Option D", "Correctly applied dental floss can remove up to 80% of interproximal plaque, reaching 2-3 mm deep."])

# 91-100: Non-Surgical Treatment, SRP, and Maintenance
q.append(["What is the ultimate clinical goal of non-surgical periodontal treatment (Scaling and Root Planing)?", "To extract hopeless teeth", "To regenerate lost alveolar bone completely", "Closure of the periodontal pocket (PD <= 4mm and no BOP)", "To apply systemic antibiotics indefinitely", "To place dental implants", "Option C", "The ultimate goal is the closure of the periodontal pocket, defined by probing depth <= 4 mm and absence of bleeding on probing."])
q.append(["In manual instrumentation, which curette features a terminal shank that is 3 mm longer than standard, designed to access deeper pockets?", "Universal curette", "Sickle scaler", "After Five extended shank curette", "Mini-Five curette", "Hoe scaler", "Option C", "After Five extended shank curettes have a terminal shank 3 mm longer, allowing access to deeper pockets (>5 mm)."])
q.append(["Why are sickle scalers contraindicated for subgingival root planing?", "They are too flexible", "They have a third cutting edge ending in a sharp point that could damage soft tissues", "They cannot remove supragingival calculus", "They are made of plastic", "They only fit in furcations", "Option B", "Sickle scalers have three cutting edges ending in a point, making them unsafe for subgingival use as they could lacerate soft tissues."])
q.append(["Ultrasonic devices in periodontics operate at frequencies above what threshold?", "1,000 Hz", "5,000 Hz", "10,000 Hz", "20,000 Hz", "100,000 Hz", "Option D", "Ultrasonic devices operate at frequencies above 20,000 Hz."])
q.append(["What effect of ultrasonic scaling creates fluid flows within the biofilm, creating evaporation zones that kill anaerobic bacteria?", "Bacterial cavitation", "Acoustic microstreaming", "Continuous lavage", "Piezoelectric shock", "Thermal ablation", "Option B", "Acoustic microstreaming creates fluid flows that separate the biofilm and generate evaporation zones with oxygen, killing anaerobes."])
q.append(["Which type of dental restoration is contraindicated for cleaning with an ultrasonic scaler due to the risk of chipping?", "Composite resin", "Amalgam", "Gold crowns", "Metal-ceramic (porcelain) crowns", "Glass ionomer", "Option D", "Metal-ceramic crowns should not be cleaned with ultrasound, as the porcelain vibrates differently from metal and may detach or chip."])
q.append(["When a bicarbonate polishing device is used, what precaution must be taken regarding the patient's eyes?", "The patient must keep their eyes closed tightly", "The patient must wear lead-lined glasses", "Patients wearing contact lenses must remove them or wear protective goggles to prevent scratching", "No precaution is necessary", "The patient must look downwards", "Option C", "Bicarbonate particles can scratch and damage contact lenses, so they must be removed or adequately protected with goggles."])
q.append(["Following active periodontal therapy (SRP), when is the comprehensive clinical re-evaluation typically performed?", "24 hours later", "1 week later", "4 - 8 weeks later", "6 months later", "1 year later", "Option C", "A practical and widely accepted approach is to perform a comprehensive clinical re-evaluation at 4-8 weeks after completion of therapy."])
q.append(["In Supportive Periodontal Therapy (Maintenance), how often should a high-risk patient with poor hygiene be scheduled?", "Every 1 - 2 weeks", "Every 3 - 4 months", "Every 6 - 8 months", "Once a year", "Every 2 years", "Option B", "High-risk patients or those with poor hygiene require shorter intervals, typically every 3-4 months."])
q.append(["According to studies, if a treated periodontitis patient is NOT placed on a maintenance program, subgingival bacterial recolonization to baseline levels typically occurs within what timeframe?", "1-2 days", "2 weeks", "9 to 11 weeks (approx. 2 months)", "6 months", "2 years", "Option C", "Periodontal pathogens can return to baseline levels within approximately 9 to 11 weeks without effective maintenance."])

df = pd.DataFrame(q, columns=cols)
df.to_csv('gemini.csv', index=False)
print("CSV generated successfully with 100 questions.")
# Out:
# CSV generated successfully with 100 questions.

# %%
import pandas as pd

cols = ['Question', 'Option A', 'Option B', 'Option C', 'Option D', 'Option E', 'Correct Answer', 'Explanation']
questions = []

# 1-10: Periodontal anatomy and microanatomy (based on PDF pages 1-28)
questions.append(["What is the main function of the periodontium?", "To form enamel", "To fix the tooth to the bone tissue with elasticity", "To regenerate dentin", "To form the pulp", "To nourish the crown", "Option B", "The periodontium fixes the tooth to the bone tissue with some elasticity and maintains oral mucosa integrity."])
questions.append(["Which of the following is NOT a component of the periodontium?", "Gingiva", "Periodontal ligament", "Cementum", "Alveolar bone", "Dentin", "Option E", "The periodontium consists of the gingiva, periodontal ligament, cementum, and alveolar bone."])
questions.append(["What constitutes the protective periodontium?", "Cementum and alveolar bone", "Gingiva and junctional epithelium", "Periodontal ligament and cementum", "Alveolar bone and periodontal ligament", "Dentin and pulp", "Option B", "The protective periodontium is formed by the gingiva and the dentogingival junction (junctional epithelium)."])
questions.append(["What is the normal probing depth of a clinically healthy gingival sulcus?", "0-1 mm", "1-2 mm", "2-3 mm", "4-5 mm", ">5 mm", "Option C", "The gingival sulcus is V-shaped and allows entry of a periodontal probe with depths considered clinically healthy from 2 to 3mm."])
questions.append(["Which part of the gingiva is firmly attached to the underlying periosteum?", "Free gingiva", "Interdental papilla", "Attached gingiva", "Marginal gingiva", "Sulcular epithelium", "Option C", "The attached gingiva is firm, resistant, and joins strongly to the underlying periosteum. It extends to the mucogingival junction."])
questions.append(["The width of attached gingiva:", "Decreases with age", "Is stable throughout life", "Increases with age, especially at puberty", "Is the same in all areas of the mouth", "Is not an important clinical parameter", "Option C", "The width of attached gingiva increases with age, especially at the time of puberty."])
questions.append(["What is the zenith of the gingival margin?", "The most apical point of the gingival contour", "The tip of the interdental papilla", "The mucogingival junction", "The free gingival groove", "The base of the sulcus", "Option A", "The zenith is the most apical point of the contour of the gum; it is usually distally displaced."])
questions.append(["Which type of gingiva occupies the spaces between the teeth?", "Free gingiva", "Attached gingiva", "Interdental gingiva (papilla)", "Alveolar mucosa", "Marginal gingiva", "Option C", "Interdental or papillary gingiva occupies the spaces between the teeth, covering the embrasures."])
questions.append(["The mucogingival junction separates:", "Attached gingiva from alveolar mucosa", "Free gingiva from attached gingiva", "Gingiva from periodontal ligament", "Cementum from dentin", "Alveolar bone from periosteum", "Option A", "The attached gingiva extends to the mucogingival junction where it is continuous with the alveolar mucosa."])
questions.append(["Healthy gingiva is typically described as:", "Red and edematous", "Coral pink or salmon pink", "White and firm", "Yellow and stippled", "Blue-purple", "Option B", "Healthy gingiva is pale pink in color (coral pink or salmon pink) although there are normal variations."])

# 11-20: Periodontal histology (Pages 29-70)
questions.append(["Which type of epithelium covers the crest and outer surface of the marginal and attached gingiva?", "Sulcular epithelium", "Junctional epithelium", "Oral epithelium", "Gingival epithelium", "Alveolar epithelium", "Option C", "The oral epithelium covers the crest and outer surface of the marginal gingiva and the surface of the attached gingiva."])
questions.append(["What is the main cell type of the oral epithelium responsible for producing cytokeratin?", "Melanocytes", "Langerhans cells", "Merkel cells", "Keratinocytes", "Fibroblasts", "Option D", "The majority of cells of the oral epithelium are keratinocytes characterized by their ability to produce filaments of cytoplasmic keratin."])
questions.append(["Which layer of the oral epithelium contains keratohyalin and has flattened cells with no organelles?", "Basal layer", "Spinosum stratum", "Granular stratum", "Stratum corneum", "Stratum lucidum", "Option C", "The granular stratum has flattened form, lacks organelles, and contains numerous electron-dense bodies of keratohyalin."])
questions.append(["The junctional epithelium attaches to the tooth surface via:", "Desmosomes", "Hemidesmosomes and internal basal lamina", "Gap junctions", "Tight junctions", "Adherens junctions", "Option B", "The junctional epithelium has an internal basal lamina (epithelial attachment) attached to the dental surface."])
questions.append(["What is the turnover rate of the junctional epithelium?", "10-15 days", "4-6 days", "2-3 weeks", "1-2 months", "24 hours", "Option B", "The junctional epithelium is in constant renewal with a turnover rate of 4-6 days."])
questions.append(["Which cells in the gingival connective tissue are responsible for synthesis and degradation of collagen?", "Mast cells", "Macrophages", "Fibroblasts", "Plasma cells", "Neutrophils", "Option C", "Fibroblasts are the predominant cell type in the lamina propria and are responsible for synthesis, resorption and enzymatic degradation of collagen."])
questions.append(["What is the approximate thickness of the periodontal ligament?", "0.1 mm", "0.2 mm (200 μm)", "0.5 mm", "1 mm", "2 mm", "Option B", "The periodontal ligament thickness is about 0.2mm (200μm) although with high variations."])
questions.append(["Which fibers of the periodontal ligament bear the brunt of vertical masticatory stresses?", "Cresto-alveolar fibers", "Horizontal fibers", "Oblique fibers", "Apical fibers", "Inter-radicular fibers", "Option C", "Oblique fibers are the largest group and bear the brunt of vertical masticatory stresses, transforming such stresses into tension on the alveolar bone."])
questions.append(["Which type of cementum is formed first and covers the cervical third of the root?", "Cellular cementum", "Acellular cementum", "Intermediate cementum", "Hypercementosis", "Osteocementum", "Option B", "Acellular cementum is the first cementum formed and covers approximately the cervical third or half of the root."])
questions.append(["The alveolar bone proper is seen radiographically as:", "Cancellous bone", "Trabecular bone", "Lamina dura", "Haversian canal", "Periosteum", "Option C", "Alveolar bone proper is seen as the lamina dura in radiographs."])

# 21-30: Etiology of periodontal diseases (Pages 71-104)
questions.append(["According to the Non-specific Plaque Hypothesis, periodontal disease results from:", "Presence of specific bacteria", "Accumulation of plaque over time with decreased host response", "Viral infection", "Genetic defects only", "Trauma from occlusion", "Option B", "The Non-specific plaque hypothesis conceived dental plaque as a biomass and believed that periodontal disease was the result of an accumulation of plaque over time, in conjunction with a decrease in host response."])
questions.append(["The Specific Plaque Hypothesis states that:", "All plaque is equally pathogenic", "Only certain plaque is pathogenic depending on specific microorganisms", "Plaque has no role in disease", "Only supragingival plaque matters", "Only calculus causes disease", "Option B", "The Specific Plaque Hypothesis states that only certain plaque is pathogenic and its pathogenicity depends on the presence of specific microorganisms or their increase."])
questions.append(["Biofilm is defined as a bacterial community:", "Freely floating in saliva", "Attached to a surface and embedded in a self-produced extracellular matrix", "Killed by antibiotics", "Composed only of gram-positive bacteria", "Without any communication between bacteria", "Option B", "Costerton defined biofilm as a bacterial community attached to a substratum or surface, embedded in a self-produced extracellular matrix, and displaying an altered phenotype."])
questions.append(["The acquired pellicle is formed by:", "Bacterial multiplication", "Adsorption of salivary glycoproteins and antibodies", "Mineralization of plaque", "Desquamation of epithelial cells", "Food debris accumulation", "Option B", "The acquired pellicle is a layer of organic material composed of salivary glycoproteins (mucins) and antibodies."])
questions.append(["During the first 4-8 hours of plaque formation, which genus predominates?", "Actinomyces", "Fusobacterium", "Streptococcus", "Porphyromonas", "Treponema", "Option C", "During the first 4-8 hours, between 60% and 80% of the bacteria belong to the genus Streptococcus."])
questions.append(["Which bacterium is known as a 'bridging bacterium' facilitating coaggregation of T. denticola and P. gingivalis?", "A. actinomycetemcomitans", "P. gingivalis", "F. nucleatum", "P. intermedia", "T. forsythia", "Option C", "Fusobacterium nucleatum is defined as a bridging bacterium, as it facilitates the coaggregation of T. denticola and P. gingivalis."])
questions.append(["Dental calculus is:", "Soft and easily removed", "Mineralized dental plaque", "An organized biofilm without mineralization", "Materia alba", "The same as the acquired pellicle", "Option B", "Calculus is a hard deposit formed by the mineralization of dental plaque, normally covered by non-mineralized dental plaque."])
questions.append(["Which of the following is a characteristic of materia alba?", "Hard and mineralized", "Structured yellow-greyish deposit", "Soft, white accumulation of bacteria, food debris and shed cells", "Cannot be removed by irrigation", "Adheres strongly to enamel", "Option C", "Materia alba is a soft, white accumulation of bacteria, decaying food, and shed cells. It lacks an organized structure and is easily removed by irrigators."])
questions.append(["Supragingival calculus is most commonly found:", "On all teeth equally", "On lingual surfaces of mandibular incisors and buccal surfaces of maxillary first molars", "Only on posterior teeth", "Only on anterior teeth", "On occlusal surfaces", "Option B", "Supragingival calculus is commonly located adjacent to salivary ducts: buccal surfaces of maxillary first molars and lingual surfaces of mandibular incisors."])
questions.append(["Which of the following is a keystone pathogen capable of transforming a benign microbiota into a dysbiotic one?", "A. actinomycetemcomitans", "F. nucleatum", "P. gingivalis", "P. intermedia", "T. denticola", "Option C", "P. gingivalis is a keystone pathogen capable of triggering inflammation even when present in low numbers by altering the host immune response and transforming a benign microbiota into a dysbiotic one."])

# 31-40: Microbiology and host response (Pages 105-137, 138-184)
questions.append(["Which bacterial complex according to Socransky is directly associated with the severity and progression of periodontitis?", "Yellow complex", "Green complex", "Orange complex", "Red complex", "Purple complex", "Option D", "The Red complex species (P. gingivalis, T. forsythia, T. denticola) are considered pathogenic and directly associated with severity and progression of periodontal disease."])
questions.append(["Which bacterium has been strongly associated with aggressive periodontitis and can invade epithelial cells?", "P. gingivalis", "A. actinomycetemcomitans", "F. nucleatum", "P. intermedia", "C. rectus", "Option B", "Aggregatibacter actinomycetemcomitans has been strongly associated with aggressive periodontitis, possesses numerous virulence factors, and has the ability to invade epithelial cells."])
questions.append(["Gingipains are virulence factors produced by:", "A. actinomycetemcomitans", "P. gingivalis", "F. nucleatum", "T. denticola", "P. intermedia", "Option B", "P. gingivalis possesses gingipains, multifunctional proteins important in adhesion, tissue degradation, and evasion of host immune responses."])
questions.append(["In the experimental gingivitis model by Loe and Theilade, plaque accumulation led to a shift in microflora from:", "Gram-negative to Gram-positive", "Cocci to bacilli and spirochetes", "Anaerobes to aerobes", "Motile to non-motile", "Proteolytic to fermenting", "Option B", "As health progresses to periodontitis, changes include from cocci to bacilli (and spirochetes at a later stage)."])
questions.append(["According to Page and Kornman's model, periodontitis is primarily:", "A direct bacterial infection", "A host-mediated inflammatory disease", "A viral disease", "A genetic disorder", "A traumatic injury", "Option B", "Page and Kornman establish periodontitis as a multifactorial, host-mediated inflammatory disease, in which bacteria initiate the process but the host's immune response drives tissue destruction."])
questions.append(["Which pro-inflammatory mediator is mainly responsible for osteoclastic bone resorption in periodontitis?", "IL-10", "TGF-β", "Prostaglandin E2 (PGE2)", "Lipopolysaccharide (LPS)", "IL-4", "Option C", "PGE2 produces vasodilation and induces the secretion of matrix metalloproteinases and osteoclastic bone resorption, playing a fundamental role in bone destruction of periodontitis."])
questions.append(["Matrix metalloproteinases (MMPs) in periodontitis are responsible for:", "Bone formation", "Collagen synthesis", "Degradation of connective tissue", "Antibody production", "Neutrophil chemotaxis", "Option C", "MMPs are fundamental in the pathogenesis of periodontitis; their function is to allow homeostasis of connective tissue, but excess secretion leads to tissue destruction."])
questions.append(["The first line of innate immune defense in the gingival sulcus is:", "Macrophages", "T-lymphocytes", "B-lymphocytes", "Polymorphonuclear leukocytes (PMNs)", "Plasma cells", "Option D", "PMNs are the first line of innate immune defense, migrating through the junctional epithelium to phagocytose bacteria."])
questions.append(["Which of the following is a known systemic modifier that has a bidirectional relationship with periodontitis?", "Smoking", "Diabetes mellitus", "Osteoporosis", "HIV infection", "Pregnancy", "Option B", "The relationship between diabetes mellitus and periodontitis is bidirectional: periodontal treatment can positively influence glycaemic control."])
questions.append(["Drug-induced gingival enlargement (e.g., from phenytoin) is primarily due to:", "Increase in cell number (hyperplasia)", "Increase in fundamental substance secreted by fibroblasts", "Inflammation caused by poor hygiene", "Edema from allergic reaction", "Bone growth", "Option B", "Drug-induced gingival enlargement is due to an increase in the fundamental substance secreted by fibroblasts, not hyperplasia."])

# 41-50: Classification of periodontal diseases (Pages 213-302)
questions.append(["In the 2017 World Workshop classification, which terms were eliminated for periodontitis?", "Localized and Generalized", "Chronic and Aggressive", "Stage and Grade", "Plaque-induced and Non-plaque-induced", "Suprabony and Infrabony", "Option B", "The 2017 classification eliminated the terms chronic and aggressive periodontitis, replacing them with Stages and Grades."])
questions.append(["In the 2017 classification, 'Stage' describes:", "Rate of disease progression", "Severity of disease and complexity of management", "Patient's age", "Risk factors like smoking", "Response to treatment", "Option B", "Stages describe the severity of the disease and the complexity of its management."])
questions.append(["In the 2017 classification, 'Grade' provides information about:", "Number of teeth lost", "Severity of bone loss", "Rate of progression, expected response to treatment, and impact on general health", "Extent of disease (localized vs generalized)", "Probing depth", "Option C", "Grades provide information about the rate of disease progression, expected response to treatment, and impact on the patient's general health."])
questions.append(["Clinical gingival health on an intact periodontium is characterized by:", "Bleeding on probing", "Presence of erythema", "Absence of bleeding on probing, erythema, edema, and attachment loss", "Probing depth >4 mm", "Radiographic bone loss", "Option C", "Clinical gingival health on an intact periodontium includes absence of bleeding on probing, erythema, edema, and attachment and bone loss."])
questions.append(["A gingival recession with no loss of interproximal attachment (CEJ not detectable interproximally) is classified as:", "Recession Type 1 (RT1)", "Recession Type 2 (RT2)", "Recession Type 3 (RT3)", "Recession Type 4 (RT4)", "Grade A recession", "Option A", "RT1 is gingival recession with no loss of interproximal attachment. Interproximal CEJ is clinically not detectable."])
questions.append(["According to the 2017 classification, the term 'periodontal phenotype' replaces:", "Gingival biotype", "Periodontal ligament", "Alveolar bone morphology", "Junctional epithelium", "Attachment apparatus", "Option A", "The group strongly suggests adoption of 'periodontal phenotype' to describe the combination of gingival phenotype and buccal bone plate thickness, replacing the term 'biotype'."])
questions.append(["Which of the following is a characteristic of a thin periodontal phenotype?", "Decreased risk for gingival recession", "Periodontal probe visible through gingival tissue after insertion", "Thick buccal bone plate", "Increased keratinized tissue width", "Lower risk of attachment loss", "Option B", "Thin phenotype (≤1 mm) is assessed by observing the periodontal probe shining through the gingival tissue. Thin phenotype increases risk for gingival recession."])
questions.append(["Necrotizing gingivitis (NG) is characterized by:", "Slow progression", "Pain, necrosis of interdental papillae, halitosis, and pseudomembrane", "Absence of pain", "Only affecting immunocompetent patients", "No bleeding", "Option B", "NG is a painful gingival disease characterized by erythematous and inflamed tissues, ulcerations, halitosis, and decapitated interdental papillae with a grayish-white pseudomembrane."])
questions.append(["What is the primary feature of periodontitis as defined in the 2017 classification?", "Gingival bleeding", "Calculus presence", "Loss of clinical attachment (radiographic bone loss, pocket formation, recession)", "Tooth mobility", "Pain on chewing", "Option C", "The primary feature of periodontitis is loss of clinical attachment, assessed by radiographic alveolar bone loss, periodontal pocket formation, and gingival recession."])
questions.append(["In the 2017 classification, if a patient has a history of periodontitis but after treatment shows no bleeding on probing and stable attachment, they are considered:", "Healthy, but at increased risk of recurrent progression", "Cured of periodontitis", "Still having active periodontitis", "In remission permanently", "Unable to be classified", "Option A", "Successfully treated and stable periodontitis patients remain at increased risk of recurrent progression of periodontitis, though they have clinical gingival health."])

# 51-60: Radiographic exploration (Pages 303-347)
questions.append(["Which radiographic technique provides the most accurate projection of alveolar bone level?", "Bisecting-angle technique", "Long-cone paralleling technique", "Panoramic radiography", "Cephalometric radiography", "Occlusal radiography", "Option B", "The long-cone paralleling technique provides a more accurate projection of the alveolar bone level compared to the bisecting-angle technique which elongates the image."])
questions.append(["The lamina dura appears radiographically as:", "A radiolucent line around the root", "A thin radiopaque line adjacent to the periodontal ligament", "An area of bone loss", "A fuzzy indistinct outline", "A dark shadow at the root apex", "Option B", "Lamina dura is a thin radiopaque line adjacent to the periodontal ligament and at the alveolar crest, representing the cortical bone lining the dental alveolus."])
questions.append(["Radiographic changes in periodontitis are not visible until:", "Inflammation reaches the gingiva", "Sufficient mineralized tissue has been lost", "The pocket depth exceeds 5 mm", "The patient reports pain", "There is suppuration", "Option B", "Radiography does not reveal early destructive changes in bone because enough mineralized tissue removal is required to be reflected. Slight changes indicate disease has progressed beyond initial stages."])
questions.append(["Horizontal bone loss on a radiograph is characterized by:", "Angular defects along the root", "Reduction in height of crest and interdental septa occurring horizontally", "Crater-like defects", "Radiolucency in furcation area", "Wedge-shaped radiolucency pointing to the root", "Option B", "Horizontal bone loss is a reduction in the height of the crest and interdental septa, occurring horizontally and perpendicular to the long axis of the teeth."])
questions.append(["Which of the following is a limitation of conventional radiography in assessing furcation lesions?", "Furcation lesions are always visible", "Root superimposition or incorrect angulation may mask furcation involvement", "Radiographs overestimate furcation bone loss", "Only vertical bone loss is detectable", "Furcations cannot be imaged at all", "Option B", "Furcation involvement may be masked due to root superimposition or incorrect angulation of the X-ray beam. Bone loss is always greater than what is shown on the radiograph."])
questions.append(["To assist in detecting interdental craters radiographically, the clinician should:", "Use only panoramic radiographs", "Place a radiopaque probe in the pocket before taking the radiograph", "Rely solely on clinical probing", "Increase the exposure time", "Use bitewing radiographs only", "Option B", "The use of radiopaque indicators (e.g., periodontal probes) placed in the periodontal pocket shows the true extent of the bone lesion on radiographs."])
questions.append(["Which of the following is a radiographic sign of trauma from occlusion?", "Narrowing of the periodontal ligament space", "Increased thickness of the lamina dura", "Widening of the periodontal ligament space and loss of lamina dura", "Increased bone density", "Root resorption always visible", "Option C", "The injury phase of trauma from occlusion produces loss of lamina dura and widening of the PDL space. The repair phase also shows widening of PDL space."])
questions.append(["Which advanced imaging modality is commonly used for three-dimensional evaluation of periodontal bone defects?", "Intraoral periapical radiography", "Bitewing radiography", "Cone beam computed tomography (CBCT)", "Panoramic radiography", "Cephalometric radiography", "Option C", "CBCT is an advanced imaging modality that provides three-dimensional evaluation of alveolar bone, furcations, and bone defects."])
questions.append(["The ALARA principle in radiography stands for:", "As Low As Reasonably Achievable", "Always Limit Annual Radiation Absorption", "Average Level of Acceptable Radiation", "As Long As Radiation is Allowed", "Acute Low-dose Radiation Assessment", "Option A", "The ALARA principle (as low as reasonably achievable) must be considered when choosing imaging modalities to balance diagnostic benefits against potential biological cost."])
questions.append(["According to Prichard's criteria for a diagnostic periapical radiograph, which is correct?", "Occlusal surfaces should not be visible", "Interproximal spaces should be overlapped", "Enamel layer and pulp chamber must be distinguished", "Proximal contacts should overlap", "Molar cusps should not be visible", "Option C", "Prichard's criteria include: show cusps of molars, distinguish enamel and pulp chamber, open interproximal spaces, no overlapping of proximal contacts."])

# 61-70: Clinical examination and prognosis (Pages 348-396)
questions.append(["According to Lang et al. (1991), the absence of bleeding on probing has a negative predictive value of:", "6%", "50%", "98%", "75%", "30%", "Option C", "Absence of bleeding on probing is a strong indicator of periodontal health with a negative predictive value of 98%."])
questions.append(["What is the definition of clinical attachment level (CAL)?", "The depth of the gingival sulcus", "The distance from the CEJ to the base of the pocket", "The amount of gingival recession", "The width of keratinized gingiva", "The mobility grade of a tooth", "Option B", "Clinical attachment level refers to the distance from the cementoenamel junction to the bottom of the periodontal pocket, representing the extent of support loss."])
questions.append(["According to McGuire and Nunn's prognosis system, a 'questionable prognosis' includes:", "Class I furcation", "25% attachment loss", "Attachment loss ≥50% with unfavorable crown-root ratio or Class II/III furcation", "No attachment loss", "Mobility Grade I", "Option C", "Questionable prognosis includes attachment loss ≥50% and an unfavorable crown-root ratio, Class II furcation, or Class III furcation."])
questions.append(["Which of the following is a poor prognostic factor for a tooth?", "Divergent roots", "Short root length", "Wide periodontal ligament space", "Healthy attached gingiva", "Shallow probing depth", "Option B", "If the root length is short, the periodontium will be more susceptible to occlusal trauma, negatively affecting prognosis."])
questions.append(["What is the primary reason that root concavities negatively affect periodontal prognosis?", "They are prone to caries", "They are areas very difficult to clean, even though they increase attachment surface", "They cause root resorption", "They prevent cementum formation", "They are always associated with enamel pearls", "Option B", "Root concavities (e.g., in mandibular first premolars, maxillary first molar mesiobuccal root) are difficult to clean, acting as plaque-retentive factors."])
questions.append(["Which of the following furcation grades indicates that the probe passes through the entire width of the furcation?", "Grade 1 (Initial)", "Grade 2 (Open)", "Grade 3 (Complete)", "Grade 4 (Advanced)", "Grade 0 (No involvement)", "Option C", "Grade 3 furcation: the probe passes through the entire width of the tooth crown from one side to the other (through-and-through)."])
questions.append(["What is the recommended force for probing when using the CPITN index?", "0.1 N", "0.25 N", "0.5 N", "1 N", "2 N", "Option B", "Probing with the CPITN probe is performed with approximately 0.25 N force."])
questions.append(["In the CPITN index, a code of 4 indicates:", "Healthy periodontium", "Bleeding on probing", "Calculus", "Probing depth 3.5-5.5 mm", "Probing depth ≥5.5 mm (black band disappears subgingivally)", "Option E", "Code 4: Probing depths 5.5mm or more, the black band disappears subgingivally."])
questions.append(["Which teeth are the 'Ramfjord teeth' used in the Periodontal Index (PDI)?", "16, 21, 24, 36, 41, 44", "11, 16, 26, 31, 36, 46", "All first molars and incisors", "All second molars", "Third molars", "Option A", "The Ramfjord teeth are 16; 21, 24; 36; 41 and 44. If missing, distal neighbor is substituted."])
questions.append(["According to the PDF, what is the most common cause of halitosis (approximately 60%)?", "Gastrointestinal disorders", "Sinusitis", "Periodontal disease", "Tongue coating", "Medications", "Option C", "Approximately 60% of halitosis cases are associated with periodontal disease."])

# 71-80: Treatment (non-surgical and surgical) (Pages 488-511)
questions.append(["What is the ultimate goal of non-surgical periodontal treatment?", "Complete removal of all calculus", "Elimination of all oral bacteria", "Closure of the periodontal pocket (probing depth ≤4 mm and no bleeding on probing)", "Regeneration of alveolar bone", "Reduction of tooth mobility to Grade 0", "Option C", "The ultimate goal is the closure of the periodontal pocket, defined by a probing depth ≤4 mm and absence of bleeding on probing."])
questions.append(["Which of the following is a limitation of scaling and root planing (SRP)?", "It completely removes all endotoxins", "It is effective in all pocket depths equally", "The amount of residual calculus is directly proportional to probing depth", "It has no adverse effects", "It does not require operator skill", "Option C", "The narrower and deeper the pockets, the more difficult it is to remove calculus. The amount of residual calculus is directly proportional to probing depth."])
questions.append(["Which curette is specifically designed for subgingival debridement in deep pockets (>5 mm) and has a longer shank?", "Universal curette", "Gracey curette", "After Five extended shank curette", "Sickle scaler", "Hoe", "Option C", "After Five curettes have a terminal shank 3 mm longer, allowing access to deeper pockets (>5 mm)."])
questions.append(["Ultrasonic scalers operate at frequencies:", "Below 2,000 Hz", "Between 2,000 and 10,000 Hz", "Above 20,000 Hz", "Exactly 15,000 Hz", "Below 1,000 Hz", "Option C", "Ultrasonic devices operate above 20,000 Hz (up to 50,000 Hz). Sonic devices operate between 2,000 and 15,000 Hz."])
questions.append(["What advantage does ultrasonic instrumentation have over manual instrumentation?", "Greater tactile sensitivity", "Lower risk of damaging cementum", "Removal of bacteria through cavitation, acoustic streaming, and lavage", "No need for water cooling", "No noise or vibration", "Option C", "Ultrasound removes bacteria via cavitation (bactericidal), acoustic microstreaming (separates biofilm), and continuous lavage (flushes debris)."])
questions.append(["Which of the following is a contraindication for using an ultrasonic scaler in some patients?", "Diabetes", "Pacemaker (older continuous-rhythm type; caution advised)", "Asthma", "Hypertension", "Pregnancy", "Option B", "Ultrasonic scalers are contraindicated in patients with older (continuous-rhythm) pacemakers; modern demand-type are generally safe but caution is advised."])
questions.append(["The Bass brushing technique is primarily designed to:", "Clean interproximal areas only", "Polish the occlusal surfaces", "Disrupt plaque at the gingival margin and inside the sulcus", "Massage the attached gingiva", "Remove stains from tobacco", "Option C", "The Bass technique (45° angle toward sulcus, vibratory movements) is designed to disrupt plaque at the gingival margin and inside the sulcus."])
questions.append(["Dental floss, when used correctly, can remove plaque up to what depth subgingivally?", "1 mm", "2-3 mm", "5 mm", "The entire pocket depth", "It cannot remove subgingival plaque", "Option B", "Dental floss removes up to 80% interproximal plaque and goes 2-3 mm deep subgingivally."])
questions.append(["What is the recommended replacement interval for a manual toothbrush based on the PDF?", "Every month", "Every 3-4 months based on degree of wear (bent, splayed bristles)", "Every 6 months", "Once a year", "Only when the color fades", "Option B", "Toothbrushes should be replaced every 3-4 months, but more importantly based on bristle wear (e.g., bent, splayed, frayed)."])
questions.append(["Which of the following is an advantage of manual curettes over ultrasonic scalers?", "Faster instrumentation", "Less operator fatigue", "Greater tactile sensitivity and lower risk of post-treatment sensitivity", "Better adaptation to furcations", "Produces no contaminated aerosols", "Option C", "Manual curettes offer greater tactile sensitivity and lower risk of damaging cementum/dentin, and produce less post-treatment sensitivity compared to ultrasonics."])

# 81-90: Chemical plaque control (Pages 404-452)
questions.append(["Chlorhexidine (CHX) is classified as a 2nd generation antiseptic because of its:", "Low substantivity (<6 hours)", "High substantivity (8-12 hours)", "Narrow antimicrobial spectrum", "Inability to adhere to oral surfaces", "Poor clinical efficacy", "Option B", "2nd generation agents (CHX) have high substantivity (8-12 hours), allowing once or twice daily use and reducing plaque by 70-90%."])
questions.append(["The mechanism of action of chlorhexidine at high concentrations is:", "Bacteriostatic only", "Inhibits bacterial adhesion only", "Bactericidal by precipitating plasma proteins", "Interferes with acquired pellicle formation only", "Competes for essential nutrients", "Option C", "At high concentrations, CHX precipitates plasma proteins causing cell death (bactericidal); at low concentrations it is bacteriostatic."])
questions.append(["To maximize the efficacy of chlorhexidine mouthwash, patients should:", "Use it immediately after brushing", "Use it at the same time as brushing", "Wait 30 minutes after brushing before using CHX, as toothpaste inactivates it", "Use it without water", "Use it only once a week", "Option C", "CHX is inactivated by anionic agents (sodium lauryl sulfate) in toothpaste. Wait 30 min between brushing and rinsing."])
questions.append(["Which of the following is a common side effect of chlorhexidine mouthwash?", "Tooth whitening", "Increased supragingival calculus deposits", "Enamel erosion", "Increased caries risk", "Gingival hyperplasia", "Option B", "CHX increases supragingival calculus deposits due to pyrophosphatase release from dead bacteria, which then calcify."])
questions.append(["Essential oils mouthwash (Listerine) contains which of the following?", "Chlorhexidine", "Cetylpyridinium chloride", "Menthol, thymol, eucalyptol", "Triclosan", "Fluoride", "Option C", "Essential oils mouthwashes contain menthol, thymol, and eucalyptol."])
questions.append(["Triclosan is often combined with which metal salt for a synergistic anti-plaque effect?", "Sodium fluoride", "Stannous fluoride", "Zinc citrate", "Potassium nitrate", "Calcium glycerophosphate", "Option C", "Triclosan is more effective when associated with metallic salts like Zinc Citrate/Zinc Lactate for a synergistic effect."])
questions.append(["Systemic antibiotic treatment in periodontics is considered:", "First-line treatment", "A replacement for scaling and root planing", "An adjunctive treatment for specific severe or aggressive cases", "Always necessary after surgery", "Only for children", "Option C", "Systemic antibiotics are adjunctive, not a substitute for conventional mechanical therapy. They are indicated for severe, advanced, aggressive periodontitis, abscesses, etc."])
questions.append(["Which antibiotic is especially effective against strict anaerobic Gram-negative bacteria like P. gingivalis?", "Amoxicillin", "Metronidazole", "Clindamycin", "Azithromycin", "Doxycycline", "Option B", "Metronidazole has a bactericidal effect by denaturing DNA and is especially effective on Gram-negative strict anaerobic bacteria."])
questions.append(["According to the PDF, probiotics in the oral cavity may exert beneficial effects by:", "Replacing chlorhexidine", "Directly killing viruses", "Immune regulation, producing antimicrobial substances, and competing for nutrients", "Increasing calculus formation", "Causing tooth staining", "Option C", "Probiotics act via immune regulation (increasing phagocytosis), production of antimicrobial substances (lactic acid, bacteriocins), and exclusion mechanisms."])
questions.append(["Which of the following is an indication for the use of antiseptic mouthwashes in periodontics?", "As a replacement for brushing", "During the hygienic phase if oral hygiene is inadequate or inflammation persists", "Only for caries prevention", "Only for halitosis", "Only before surgery", "Option B", "Mouthwashes are indicated during the hygienic phase simultaneously or after SRP if oral hygiene is inadequate and/or inflammation persists, and in maintenance for localized pockets."])

# 91-100: Periodontal maintenance (Pages 512-535)
questions.append(["Periodontal maintenance (Supportive Periodontal Therapy) is defined as:", "A preventive procedure for healthy patients", "A therapeutic procedure performed in patients with history of periodontitis to prevent recurrence", "The same as routine prophylaxis", "Only necessary after implant placement", "A one-time treatment", "Option B", "Periodontal maintenance is a therapeutic procedure performed in patients with a history of periodontitis to control a chronic disease and prevent recurrence."])
questions.append(["What is the primary biological rationale for periodontal maintenance?", "To whiten the teeth", "To prevent calculus formation permanently", "Biofilm reforms immediately after treatment, and pathogens can return to baseline within 9-11 weeks", "To reduce tooth sensitivity", "To improve smile aesthetics", "Option C", "The causative biofilm reforms immediately, and periodontal pathogens can return to baseline levels within approximately 9 to 11 weeks, requiring regular maintenance."])
questions.append(["After active periodontal therapy, clinical re-evaluation to establish the maintenance protocol is typically performed at:", "1 week", "2-3 days", "4-8 weeks", "6 months", "1 year", "Option C", "Connective tissue repair occurs between 4 and 8 weeks, and subgingival bacterial recolonization is observed after about 2 months, so re-evaluation at 4-8 weeks is practical."])
questions.append(["In a high-risk patient (poor hygiene, smoker), what recall interval is recommended?", "Every 6-12 months", "Every 3-4 months", "Once a year", "Every 2 years", "Only when symptoms appear", "Option B", "High-risk / poor hygiene patients should have shorter intervals of 3-4 months. Low-risk patients may have 6-12 month intervals."])
questions.append(["What is the difference between periodontal maintenance and prophylaxis?", "Maintenance is for healthy patients; prophylaxis is for periodontitis patients", "Prophylaxis is a preventive procedure for healthy patients; maintenance is a therapeutic procedure for patients with history of periodontitis", "There is no difference", "Maintenance is more expensive", "Prophylaxis includes radiographs", "Option B", "Prophylaxis is a preventive procedure in periodontally healthy patients; maintenance (SPT) is a therapeutic procedure in patients with history of periodontitis to control chronic disease."])
questions.append(["Which of the following is a warning sign of disease recurrence during a maintenance visit?", "Probing depth 2 mm with no bleeding", "Bleeding on probing and increased probing depth", "Absence of suppuration", "Stable clinical attachment level", "Good plaque control", "Option B", "Warning signs include increased probing depth (PD), bleeding on probing (BOP), loss of clinical attachment (CAL), and presence of suppuration."])
questions.append(["What is included in a typical periodontal maintenance visit?", "Only supragingival polishing", "Mechanical debridement (ultrasonic + curettes), reinforcement of oral hygiene, and assessment of periodontal parameters", "Only oral hygiene instructions", "Only radiographs", "Only extraction of mobile teeth", "Option B", "A maintenance visit includes mechanical debridement (supra- and subgingival biofilm/calculus removal), reinforcement of oral hygiene, and assessment of PD, BOP, CAL, etc."])
questions.append(["Why is subgingival cleaning essential during periodontal maintenance?", "To whiten the roots", "To remove stains", "Periodontal pathogens are primarily located in periodontal pockets", "To reduce tooth mobility permanently", "To eliminate supragingival plaque", "Option C", "Subgingival cleaning is essential because periodontal pathogens are primarily located in periodontal pockets, not just supragingivally."])
questions.append(["After successful periodontal treatment, a patient who quits smoking will likely have:", "No change in prognosis", "Worsened prognosis", "Improved prognosis compared to continuing smokers", "The same prognosis as a non-smoker immediately", "Permanent attachment loss reversal", "Option C", "Patients with periodontal disease who quit smoking improve their prognosis. Smoking negatively affects healing and treatment response."])
questions.append(["What is the main objective of the maintenance phase?", "To perform complex restorative procedures", "To prevent reinfection and recurrence of periodontal disease", "To whiten the teeth", "To extract all remaining teeth", "To place dental implants", "Option B", "The purpose of the maintenance phase is the prevention of reinfection and recurrence of the disease, due to patient susceptibility and high risk of recurrence."])

import csv
# Create DataFrame and save to CSV
df = pd.DataFrame(questions, columns=cols)
df.to_csv('deepseek.csv', index=False, encoding='utf-8', quoting=csv.QUOTE_ALL)
print(f"CSV file generated with {len(questions)} questions.")
# Out:
# CSV file generated with 100 questions.
